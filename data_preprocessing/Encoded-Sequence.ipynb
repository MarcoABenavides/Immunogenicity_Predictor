# %%
import os
import glob
import numpy as np
import pandas as pd
from Bio import PDB

# One-hot encoding map for 20 amino acids
AA_CODES = [
    "ALA", "ARG", "ASN", "ASP", "CYS", "GLN", "GLU", "GLY", "HIS", "ILE",
    "LEU", "LYS", "MET", "PHE", "PRO", "SER", "THR", "TRP", "TYR", "VAL"
]
AA_TO_INDEX = {aa: idx for idx, aa in enumerate(AA_CODES)}

# Function to extract amino acid sequence from PDB file
def extract_sequence_from_pdb(pdb_path):
    parser = PDB.PDBParser(QUIET=True)
    structure = parser.get_structure("protein", pdb_path)
    sequence = []

    for model in structure:
        for chain in model:
            for residue in chain:
                resname = residue.get_resname()
                if resname in AA_TO_INDEX:
                    sequence.append(resname)
    return sequence

# One-hot encoding function
def one_hot_encode_sequence(sequence):
    onehot = np.zeros((len(sequence), len(AA_CODES)), dtype=int)
    for i, aa in enumerate(sequence):
        if aa in AA_TO_INDEX:
            onehot[i, AA_TO_INDEX[aa]] = 1
    return onehot

# Base path and dataset folders
base_path = "/Users/marcobenavides/Documents/Columbia University/Spring 2025/DL Biomedical Imaging/Project"
dataset_folders = [
    "protein_antigens_non-immunogenic",
    "protein_antigens_immunogenic",
    "bacterial_non_antigens",
    "bacterial_antigens"
]

# Process each dataset folder
for folder in dataset_folders:
    pdb_folder = os.path.join(base_path, folder, "pdb_files")
    voronoi_folder = os.path.join(base_path, folder, "voronoi_images")
    output_folder = os.path.join(base_path, folder, "onehot_sequences")
    os.makedirs(output_folder, exist_ok=True)

    pdb_files = glob.glob(os.path.join(pdb_folder, "*.pdb"))

    for pdb_file in pdb_files:
        pdb_name = os.path.splitext(os.path.basename(pdb_file))[0]
        csv_path = os.path.join(output_folder, f"{pdb_name}_onehot.csv")

        # Skip if output CSV already exists
        if os.path.exists(csv_path):
            print(f"One-hot file already exists for {pdb_name}, skipping.")
            continue

        # Check for possible Voronoi image naming variations
        voronoi_standard = os.path.join(voronoi_folder, f"{pdb_name}.png")
        voronoi_notstandard = os.path.join(voronoi_folder, f"{pdb_name}.pdb.png")
        voronoi_af_remote = os.path.join(voronoi_folder, f"AF_REMOTE_{pdb_name}.png")
        voronoi_pdb_prefix = os.path.join(voronoi_folder, f"PDB_{pdb_name}.png")

        if os.path.exists(voronoi_standard) or os.path.exists(voronoi_af_remote) or os.path.exists(voronoi_pdb_prefix) or os.path.exists(voronoi_notstandard):
            sequence = extract_sequence_from_pdb(pdb_file)
            if sequence:
                onehot = one_hot_encode_sequence(sequence)
                df = pd.DataFrame(onehot, columns=AA_CODES)
                df.to_csv(csv_path, index=False)
                print(f"Saved one-hot encoding for {pdb_name} to {csv_path}")
            else:
                print(f"No valid amino acid sequence found in {pdb_name}")
        else:
            print(f"Voronoi image not found for {pdb_name}, skipping.")
# Out:
# One-hot file already exists for AF-K7EMK9-F1, skipping.
# One-hot file already exists for 6obd, skipping.
# One-hot file already exists for AF-A0A7I2V363-F1, skipping.
# One-hot file already exists for AF-F8VP99-F1, skipping.
# One-hot file already exists for AF-A0A191URJ7-F1, skipping.
# One-hot file already exists for AF-M0R2M5-F1, skipping.
# One-hot file already exists for AF-H0YNH3-F1, skipping.
# One-hot file already exists for 7p0p, skipping.
# One-hot file already exists for AF-Q86SH4-F1, skipping.
# One-hot file already exists for AF-A0A096LPD5-F1, skipping.
# One-hot file already exists for AF-F5H6I1-F1, skipping.
# One-hot file already exists for AF-Q5STR5-F1, skipping.
# One-hot file already exists for 2p31, skipping.
# One-hot file already exists for AF-C9J8Y3-F1, skipping.
# One-hot file already exists for AF-Q5SRE5-F1, skipping.
# One-hot file already exists for AF-A0A6Q8PGV7-F1, skipping.
# One-hot file already exists for AF-P62829-F1, skipping.
# One-hot file already exists for AF-Q9H5J4-F1, skipping.
# One-hot file already exists for AF-Q86YD1-F1, skipping.
# One-hot file already exists for AF-Q5PR19-F1, skipping.
# One-hot file already exists for AF-Q9NY30-F1, skipping.
# One-hot file already exists for AF-Q93070-F1, skipping.
# One-hot file already exists for AF-P82932-F1, skipping.
# One-hot file already exists for AF-D2DTW1-F1, skipping.
# One-hot file already exists for AF-G3V3R1-F1, skipping.
# One-hot file already exists for AF-C9J9Z5-F1, skipping.
# One-hot file already exists for AF-A0A1B0GV95-F1, skipping.
# One-hot file already exists for 2qc7, skipping.
# One-hot file already exists for AF-B7Z2R4-F1, skipping.
# One-hot file already exists for AF-B6ZDM2-F1, skipping.
# One-hot file already exists for AF-C9J4C4-F1, skipping.
# One-hot file already exists for AF-F8WF73-F1, skipping.
# One-hot file already exists for AF-A0A7P0T9P8-F1, skipping.
# One-hot file already exists for AF-A0A096LP34-F1, skipping.
# One-hot file already exists for AF-H3BQL8-F1, skipping.
# One-hot file already exists for AF-A0A087WTJ4-F1, skipping.
# One-hot file already exists for AF-P0C7P4-F1, skipping.
# One-hot file already exists for AF-F8VZG4-F1, skipping.
# One-hot file already exists for AF-B4DEE8-F1, skipping.
# One-hot file already exists for 8ffv, skipping.
# One-hot file already exists for AF-F5GWD9-F1, skipping.
# One-hot file already exists for AF-Q6ZS30-F1, skipping.
# One-hot file already exists for AF-A0A2R8Y7A4-F1, skipping.
# One-hot file already exists for AF-A0A6Q8PFY4-F1, skipping.
# One-hot file already exists for AF-E9PQ12-F1, skipping.
# One-hot file already exists for AF-A0A0U1RR55-F1, skipping.
# One-hot file already exists for AF-V9GYT2-F1, skipping.
# One-hot file already exists for AF-P42167-F1, skipping.
# One-hot file already exists for AF-Q96SE0-F1, skipping.
# One-hot file already exists for AF-E9PSI3-F1, skipping.
# One-hot file already exists for AF-M0QXU7-F1, skipping.
# One-hot file already exists for AF-D6RB80-F1, skipping.
# One-hot file already exists for AF-I3L463-F1, skipping.
# One-hot file already exists for AF-F5H5J4-F1, skipping.
# One-hot file already exists for AF-A0A7P0T8I1-F1, skipping.
# One-hot file already exists for AF-A0A6I8PL32-F1, skipping.
# One-hot file already exists for 7vg7, skipping.
# One-hot file already exists for AF-E9PML8-F1, skipping.
# One-hot file already exists for AF-M0QYF4-F1, skipping.
# One-hot file already exists for AF-A0A1B0GWA7-F1, skipping.
# One-hot file already exists for AF-A0A804HJC5-F1, skipping.
# One-hot file already exists for AF-A0A804HIH2-F1, skipping.
# One-hot file already exists for AF-F8W961-F1, skipping.
# One-hot file already exists for AF-F5H3I6-F1, skipping.
# One-hot file already exists for AF-J9JIG0-F1, skipping.
# One-hot file already exists for AF-A0A140T989-F1, skipping.
# One-hot file already exists for AF-H0YKJ0-F1, skipping.
# One-hot file already exists for AF-A4IF30-F1, skipping.
# One-hot file already exists for AF-E5RJZ4-F1, skipping.
# One-hot file already exists for AF-Q5JYA8-F1, skipping.
# One-hot file already exists for AF-A0A1B0GTI6-F1, skipping.
# One-hot file already exists for AF-I3L1H5-F1, skipping.
# One-hot file already exists for 7mqz, skipping.
# One-hot file already exists for AF-A8MWL6-F1, skipping.
# One-hot file already exists for AF-C9JTW8-F1, skipping.
# One-hot file already exists for AF-Q9BU20-F1, skipping.
# One-hot file already exists for AF-A0A2R8Y7B2-F1, skipping.
# One-hot file already exists for AF-A0A0J9YXP5-F1, skipping.
# One-hot file already exists for AF-Q6UWT2-F1, skipping.
# One-hot file already exists for AF-Q5VXI9-F1, skipping.
# One-hot file already exists for AF-C9JB70-F1, skipping.
# One-hot file already exists for AF-V9GY63-F1, skipping.
# One-hot file already exists for AF-A0A2R8YFH3-F1, skipping.
# One-hot file already exists for AF-A0A0A0MSR1-F1, skipping.
# One-hot file already exists for AF-Q5JW54-F1, skipping.
# One-hot file already exists for AF-I3L2S9-F1, skipping.
# One-hot file already exists for AF-A0PJX0-F1, skipping.
# One-hot file already exists for AF-Q8NFL0-F1, skipping.
# One-hot file already exists for AF-K7EL60-F1, skipping.
# One-hot file already exists for AF-C9J6Q8-F1, skipping.
# One-hot file already exists for AF-W6CW81-F1, skipping.
# One-hot file already exists for AF-A0A2U3TZH2-F1, skipping.
# One-hot file already exists for AF-J3QRV3-F1, skipping.
# One-hot file already exists for AF-F8W7Q0-F1, skipping.
# One-hot file already exists for AF-A0A2U3TZI0-F1, skipping.
# One-hot file already exists for AF-I3L277-F1, skipping.
# One-hot file already exists for AF-Q07001-F1, skipping.
# One-hot file already exists for AF-A0A0G2JLQ3-F1, skipping.
# One-hot file already exists for AF-Q86V93-F1, skipping.
# One-hot file already exists for AF-H0YG36-F1, skipping.
# One-hot file already exists for AF-Q5FBZ4-F1, skipping.
# One-hot file already exists for 2h8r, skipping.
# One-hot file already exists for AF-G3V3H0-F1, skipping.
# One-hot file already exists for AF-J3KSQ3-F1, skipping.
# One-hot file already exists for AF-Q3LXA3-F1, skipping.
# One-hot file already exists for 8jd4, skipping.
# One-hot file already exists for AF-A0A3B3IS64-F1, skipping.
# One-hot file already exists for AF-G3V3N3-F1, skipping.
# One-hot file already exists for AF-A0A1B0GXC6-F1, skipping.
# One-hot file already exists for AF-C9J951-F1, skipping.
# One-hot file already exists for AF-A0A120N617-F1, skipping.
# One-hot file already exists for AF-K7EL48-F1, skipping.
# One-hot file already exists for AF-Q9NVV5-F1, skipping.
# One-hot file already exists for 8j0o, skipping.
# One-hot file already exists for AF-C9K0V7-F1, skipping.
# One-hot file already exists for AF-A0A590UJJ7-F1, skipping.
# One-hot file already exists for AF-H0YF90-F1, skipping.
# One-hot file already exists for 3hr0, skipping.
# One-hot file already exists for AF-E7EU00-F1, skipping.
# One-hot file already exists for 1wiz, skipping.
# One-hot file already exists for AF-E5RIH8-F1, skipping.
# One-hot file already exists for AF-Q969X2-F1, skipping.
# One-hot file already exists for AF-Q16143-F1, skipping.
# One-hot file already exists for AF-Q5SZF2-F1, skipping.
# One-hot file already exists for AF-Q7Z5L4-F1, skipping.
# One-hot file already exists for AF-A2A2P3-F1, skipping.
# One-hot file already exists for AF-F8WCJ1-F1, skipping.
# One-hot file already exists for AF-H3BPJ9-F1, skipping.
# One-hot file already exists for AF-A0A5F9ZGX7-F1, skipping.
# One-hot file already exists for AF-O75298-F1, skipping.
# One-hot file already exists for AF-A0A1W2PNX9-F1, skipping.
# One-hot file already exists for AF-Q96FV3-F1, skipping.
# One-hot file already exists for AF-M0QZG7-F1, skipping.
# One-hot file already exists for AF-C9JFP1-F1, skipping.
# One-hot file already exists for AF-Q9UKG4-F1, skipping.
# One-hot file already exists for AF-A0A1W2PNX5-F1, skipping.
# One-hot file already exists for 2fbm, skipping.
# One-hot file already exists for AF-Q5JTB4-F1, skipping.
# One-hot file already exists for AF-E9PAX0-F1, skipping.
# One-hot file already exists for AF-E9PK19-F1, skipping.
# One-hot file already exists for AF-D6R9P2-F1, skipping.
# One-hot file already exists for AF-Q4ZJI4-F1, skipping.
# One-hot file already exists for AF-F8VW93-F1, skipping.
# One-hot file already exists for AF-A0A7P0T9C9-F1, skipping.
# One-hot file already exists for AF-G3V349-F1, skipping.
# One-hot file already exists for AF-F8VRP1-F1, skipping.
# One-hot file already exists for 8a9j, skipping.
# One-hot file already exists for 6fkq, skipping.
# One-hot file already exists for AF-B4DND0-F1, skipping.
# One-hot file already exists for AF-J3KR00-F1, skipping.
# One-hot file already exists for AF-A0A087WYI0-F1, skipping.
# One-hot file already exists for AF-P46721-F1, skipping.
# One-hot file already exists for AF-B1AK76-F1, skipping.
# One-hot file already exists for AF-A0A0A0MSU6-F1, skipping.
# One-hot file already exists for 7ob9, skipping.
# One-hot file already exists for AF-B0QYP2-F1, skipping.
# One-hot file already exists for AF-D6R9X8-F1, skipping.
# One-hot file already exists for AF-E7EW07-F1, skipping.
# One-hot file already exists for AF-C9J6S8-F1, skipping.
# One-hot file already exists for AF-E9PLZ8-F1, skipping.
# One-hot file already exists for AF-O00505-F1, skipping.
# One-hot file already exists for AF-H0YIE6-F1, skipping.
# One-hot file already exists for 5e8d, skipping.
# One-hot file already exists for AF-H0YF08-F1, skipping.
# One-hot file already exists for AF-F2Z2P5-F1, skipping.
# One-hot file already exists for AF-E9PP69-F1, skipping.
# One-hot file already exists for AF-A0A087WZS0-F1, skipping.
# One-hot file already exists for AF-F8WEQ0-F1, skipping.
# One-hot file already exists for 6sc2, skipping.
# One-hot file already exists for AF-B7Z8V9-F1, skipping.
# One-hot file already exists for AF-A0A286YEP9-F1, skipping.
# One-hot file already exists for AF-Q9BRT8-F1, skipping.
# One-hot file already exists for AF-A0A0B4J250-F1, skipping.
# One-hot file already exists for AF-M0R2V2-F1, skipping.
# One-hot file already exists for AF-O60762-F1, skipping.
# One-hot file already exists for AF-K7EIK4-F1, skipping.
# One-hot file already exists for AF-H3BQF8-F1, skipping.
# One-hot file already exists for AF-K7ESG8-F1, skipping.
# One-hot file already exists for AF-A0A0A0MS77-F1, skipping.
# One-hot file already exists for AF-D6RF11-F1, skipping.
# One-hot file already exists for AF-Q8IW00-F1, skipping.
# One-hot file already exists for AF-Q8NBZ9-F1, skipping.
# One-hot file already exists for AF-C9J3S3-F1, skipping.
# One-hot file already exists for AF-J3QT95-F1, skipping.
# One-hot file already exists for AF-I3L2M5-F1, skipping.
# One-hot file already exists for AF-D6REP5-F1, skipping.
# One-hot file already exists for AF-C9J5B0-F1, skipping.
# One-hot file already exists for AF-E9PS09-F1, skipping.
# One-hot file already exists for AF-F8VYK8-F1, skipping.
# One-hot file already exists for AF-E9PJ72-F1, skipping.
# One-hot file already exists for AF-A8MTZ5-F1, skipping.
# One-hot file already exists for AF-C9JAU4-F1, skipping.
# One-hot file already exists for AF-I3L2L7-F1, skipping.
# One-hot file already exists for AF-F5GX11-F1, skipping.
# One-hot file already exists for AF-A0A7I2V4C4-F1, skipping.
# One-hot file already exists for AF-Q99567-F1, skipping.
# One-hot file already exists for AF-G3V2G7-F1, skipping.
# One-hot file already exists for AF-H0Y8U4-F1, skipping.
# One-hot file already exists for 1u6t, skipping.
# One-hot file already exists for AF-H0YKT2-F1, skipping.
# One-hot file already exists for AF-F5H081-F1, skipping.
# One-hot file already exists for AF-E5RJD6-F1, skipping.
# One-hot file already exists for AF-F5H3F3-F1, skipping.
# One-hot file already exists for 3qwl, skipping.
# One-hot file already exists for 6eje, skipping.
# One-hot file already exists for AF-A0A7I2YQG7-F1, skipping.
# One-hot file already exists for AF-C9J4G5-F1, skipping.
# One-hot file already exists for AF-A0A6Q8PGV1-F1, skipping.
# One-hot file already exists for AF-F5GY35-F1, skipping.
# One-hot file already exists for AF-A0A7P0T9A5-F1, skipping.
# One-hot file already exists for AF-H0Y9F7-F1, skipping.
# One-hot file already exists for AF-D6RBV2-F1, skipping.
# One-hot file already exists for 7r89, skipping.
# One-hot file already exists for AF-E7EPM8-F1, skipping.
# One-hot file already exists for AF-Q8N1I0-F1, skipping.
# One-hot file already exists for AF-Q6JVE9-F1, skipping.
# One-hot file already exists for AF-Q6ZWI9-F1, skipping.
# One-hot file already exists for AF-A6NDX4-F1, skipping.
# One-hot file already exists for AF-E7EW87-F1, skipping.
# One-hot file already exists for AF-F8VQZ2-F1, skipping.
# One-hot file already exists for AF-A6NHT5-F1, skipping.
# One-hot file already exists for AF-A0A3B3ITN8-F1, skipping.
# One-hot file already exists for AF-A0A0D9SFH5-F1, skipping.
# One-hot file already exists for AF-C9IYP2-F1, skipping.
# One-hot file already exists for AF-S4R3T6-F1, skipping.
# One-hot file already exists for AF-P0DMS9-F1, skipping.
# One-hot file already exists for AF-F8WDI9-F1, skipping.
# One-hot file already exists for AF-A0A087WT84-F1, skipping.
# One-hot file already exists for AF-A0A494C016-F1, skipping.
# One-hot file already exists for AF-E7ERP7-F1, skipping.
# One-hot file already exists for AF-Q8N6K0-F1, skipping.
# One-hot file already exists for AF-A0A804HJM0-F1, skipping.
# One-hot file already exists for AF-A0A7I2V2P1-F1, skipping.
# One-hot file already exists for AF-X1WI27-F1, skipping.
# One-hot file already exists for AF-D6RB69-F1, skipping.
# One-hot file already exists for AF-A0A804HKL2-F1, skipping.
# One-hot file already exists for AF-C9J302-F1, skipping.
# One-hot file already exists for AF-A0A804HK97-F1, skipping.
# One-hot file already exists for AF-F5GY58-F1, skipping.
# One-hot file already exists for AF-H3BS06-F1, skipping.
# One-hot file already exists for AF-A0A1B0GUE7-F1, skipping.
# One-hot file already exists for AF-Q2HNT4-F1, skipping.
# One-hot file already exists for AF-A0A0C4DGP6-F1, skipping.
# One-hot file already exists for AF-E7ENW7-F1, skipping.
# One-hot file already exists for AF-A0A7P0TAB9-F1, skipping.
# One-hot file already exists for AF-D6RAE0-F1, skipping.
# One-hot file already exists for AF-F6T1Q0-F1, skipping.
# One-hot file already exists for 6s7o, skipping.
# One-hot file already exists for AF-F8VSL7-F1, skipping.
# One-hot file already exists for AF-E5RJN2-F1, skipping.
# One-hot file already exists for AF-D6RHF5-F1, skipping.
# One-hot file already exists for AF-F8WC01-F1, skipping.
# One-hot file already exists for AF-E5RHC6-F1, skipping.
# One-hot file already exists for AF-H0YE87-F1, skipping.
# One-hot file already exists for 6lui, skipping.
# One-hot file already exists for AF-D6RBJ0-F1, skipping.
# One-hot file already exists for AF-C9J392-F1, skipping.
# One-hot file already exists for AF-J3KTQ1-F1, skipping.
# One-hot file already exists for AF-F8WD66-F1, skipping.
# One-hot file already exists for AF-G5E9G0-F1, skipping.
# One-hot file already exists for AF-E5RHR1-F1, skipping.
# One-hot file already exists for AF-E5RIR1-F1, skipping.
# One-hot file already exists for AF-A6H8Y7-F1, skipping.
# One-hot file already exists for AF-K7EMW1-F1, skipping.
# One-hot file already exists for AF-Q6PEW3-F1, skipping.
# One-hot file already exists for AF-C9JRV6-F1, skipping.
# One-hot file already exists for AF-E9PMY0-F1, skipping.
# One-hot file already exists for AF-F5H496-F1, skipping.
# One-hot file already exists for 1bnd, skipping.
# One-hot file already exists for AF-E9PFV3-F1, skipping.
# One-hot file already exists for AF-O00519-F1, skipping.
# One-hot file already exists for AF-C9J029-F1, skipping.
# One-hot file already exists for AF-Q69YM1-F1, skipping.
# One-hot file already exists for AF-F8WE17-F1, skipping.
# One-hot file already exists for AF-C9J9P7-F1, skipping.
# One-hot file already exists for AF-M0QY65-F1, skipping.
# One-hot file already exists for 1fle, skipping.
# One-hot file already exists for AF-E5RH66-F1, skipping.
# One-hot file already exists for 5xtc, skipping.
# One-hot file already exists for AF-F8VVW8-F1, skipping.
# One-hot file already exists for AF-B7WP74-F1, skipping.
# One-hot file already exists for AF-H0YF35-F1, skipping.
# One-hot file already exists for AF-V9GYV7-F1, skipping.
# One-hot file already exists for AF-A6QRH1-F1, skipping.
# One-hot file already exists for 6j8y, skipping.
# One-hot file already exists for AF-H3BTL2-F1, skipping.
# One-hot file already exists for AF-A0A3B3IS16-F1, skipping.
# One-hot file already exists for AF-A0A5F9ZGP6-F1, skipping.
# One-hot file already exists for 7vl9, skipping.
# One-hot file already exists for AF-F8W6G9-F1, skipping.
# One-hot file already exists for 7qpg, skipping.
# One-hot file already exists for AF-A0A7I2V599-F1, skipping.
# One-hot file already exists for AF-J3QRS9-F1, skipping.
# One-hot file already exists for AF-H7C174-F1, skipping.
# One-hot file already exists for AF-F8WEP5-F1, skipping.
# One-hot file already exists for AF-H3BRJ9-F1, skipping.
# One-hot file already exists for AF-A0A0A0MTF6-F1, skipping.
# One-hot file already exists for AF-A0A2U3TZI3-F1, skipping.
# One-hot file already exists for AF-A0A087WZ51-F1, skipping.
# One-hot file already exists for AF-F8WE71-F1, skipping.
# One-hot file already exists for AF-B1AKS3-F1, skipping.
# One-hot file already exists for AF-Q9UIG8-F1, skipping.
# One-hot file already exists for AF-F8VRI7-F1, skipping.
# One-hot file already exists for AF-M0R211-F1, skipping.
# One-hot file already exists for AF-D3DX48-F1, skipping.
# One-hot file already exists for AF-H3BV16-F1, skipping.
# One-hot file already exists for AF-F8WE63-F1, skipping.
# One-hot file already exists for AF-A0A0G2JQI6-F1, skipping.
# One-hot file already exists for AF-F8VVU0-F1, skipping.
# One-hot file already exists for AF-F8VPN9-F1, skipping.
# One-hot file already exists for AF-C9JJI3-F1, skipping.
# One-hot file already exists for AF-A0A087WU81-F1, skipping.
# One-hot file already exists for AF-A0A087WZL1-F1, skipping.
# One-hot file already exists for AF-A0A1X7SC65-F1, skipping.
# One-hot file already exists for AF-C9IYC4-F1, skipping.
# One-hot file already exists for AF-A0A7P0T871-F1, skipping.
# One-hot file already exists for AF-F8VVY5-F1, skipping.
# One-hot file already exists for AF-E9PJB0-F1, skipping.
# One-hot file already exists for AF-Q5JVH2-F1, skipping.
# One-hot file already exists for AF-A0A2R8Y5A6-F1, skipping.
# One-hot file already exists for AF-U3KQC2-F1, skipping.
# One-hot file already exists for AF-Q5TC63-F1, skipping.
# One-hot file already exists for AF-A0A7I2V5F6-F1, skipping.
# One-hot file already exists for AF-E9PIJ1-F1, skipping.
# One-hot file already exists for AF-E7ETE6-F1, skipping.
# One-hot file already exists for AF-A0A2R8Y3S3-F1, skipping.
# One-hot file already exists for AF-E9PLV6-F1, skipping.
# One-hot file already exists for AF-C9J2Q0-F1, skipping.
# One-hot file already exists for AF-C9JWC4-F1, skipping.
# One-hot file already exists for AF-S4R421-F1, skipping.
# One-hot file already exists for AF-P84098-F1, skipping.
# One-hot file already exists for AF-M0R0G1-F1, skipping.
# One-hot file already exists for AF-A6PW57-F1, skipping.
# One-hot file already exists for AF-K7EQE4-F1, skipping.
# One-hot file already exists for AF-K7ELM7-F1, skipping.
# One-hot file already exists for AF-A0A087WTY8-F1, skipping.
# One-hot file already exists for 1zr5, skipping.
# One-hot file already exists for AF-H7BZ35-F1, skipping.
# One-hot file already exists for AF-H3BS37-F1, skipping.
# One-hot file already exists for AF-A2A3F8-F1, skipping.
# One-hot file already exists for AF-A0A0B4J290-F1, skipping.
# One-hot file already exists for AF-Q96SN7-F1, skipping.
# One-hot file already exists for AF-H0YN92-F1, skipping.
# One-hot file already exists for AF-C9JV47-F1, skipping.
# One-hot file already exists for AF-D6RC46-F1, skipping.
# One-hot file already exists for AF-Q9BWV2-F1, skipping.
# One-hot file already exists for AF-J3KNQ3-F1, skipping.
# One-hot file already exists for 4jlu, skipping.
# One-hot file already exists for AF-D6RE74-F1, skipping.
# One-hot file already exists for 7znl, skipping.
# One-hot file already exists for AF-Q8WVB3-F1, skipping.
# One-hot file already exists for AF-E5RGJ6-F1, skipping.
# One-hot file already exists for AF-C9J5U1-F1, skipping.
# One-hot file already exists for AF-C9J4U1-F1, skipping.
# One-hot file already exists for AF-A9J4F5-F1, skipping.
# One-hot file already exists for 6wlw, skipping.
# One-hot file already exists for AF-C9JAE4-F1, skipping.
# One-hot file already exists for AF-Q86SI9-F1, skipping.
# One-hot file already exists for AF-A0A087WWQ9-F1, skipping.
# One-hot file already exists for AF-G3V2P6-F1, skipping.
# One-hot file already exists for AF-A0A2R8Y5B2-F1, skipping.
# One-hot file already exists for AF-Q71H61-F1, skipping.
# One-hot file already exists for AF-Q08E91-F1, skipping.
# One-hot file already exists for 5z62, skipping.
# One-hot file already exists for AF-A0A2R8Y674-F1, skipping.
# One-hot file already exists for AF-F8WD38-F1, skipping.
# One-hot file already exists for AF-E9PK96-F1, skipping.
# One-hot file already exists for 3p0l, skipping.
# One-hot file already exists for 5t53, skipping.
# One-hot file already exists for AF-E5RI76-F1, skipping.
# One-hot file already exists for AF-I3L276-F1, skipping.
# One-hot file already exists for AF-P63119-F1, skipping.
# One-hot file already exists for AF-C9J165-F1, skipping.
# One-hot file already exists for AF-E9PBI9-F1, skipping.
# One-hot file already exists for AF-A0A1W2PQ25-F1, skipping.
# One-hot file already exists for AF-E9PKY3-F1, skipping.
# One-hot file already exists for AF-F8VWP7-F1, skipping.
# One-hot file already exists for AF-Q96ST8-F1, skipping.
# One-hot file already exists for AF-F5GXZ5-F1, skipping.
# One-hot file already exists for AF-E5RIF4-F1, skipping.
# One-hot file already exists for AF-G3V136-F1, skipping.
# One-hot file already exists for 4jv8, skipping.
# One-hot file already exists for AF-A0A6Q8PF92-F1, skipping.
# One-hot file already exists for AF-Q9BT76-F1, skipping.
# One-hot file already exists for AF-F8W714-F1, skipping.
# One-hot file already exists for AF-E9PKN7-F1, skipping.
# One-hot file already exists for AF-E7EMX0-F1, skipping.
# One-hot file already exists for 7f16, skipping.
# One-hot file already exists for AF-A0A0U1RQK8-F1, skipping.
# One-hot file already exists for 1www, skipping.
# One-hot file already exists for 4z3c, skipping.
# One-hot file already exists for AF-X6RL26-F1, skipping.
# One-hot file already exists for AF-A0A087X0U9-F1, skipping.
# One-hot file already exists for AF-I3L4B7-F1, skipping.
# One-hot file already exists for AF-H0YL83-F1, skipping.
# One-hot file already exists for AF-C9J7D9-F1, skipping.
# One-hot file already exists for AF-A0A804HK12-F1, skipping.
# One-hot file already exists for AF-F8VQQ1-F1, skipping.
# One-hot file already exists for AF-A0A1W2PQE4-F1, skipping.
# One-hot file already exists for AF-I3L4P6-F1, skipping.
# One-hot file already exists for AF-B2REC8-F1, skipping.
# One-hot file already exists for AF-B1ANH7-F1, skipping.
# One-hot file already exists for AF-H3BQ34-F1, skipping.
# One-hot file already exists for AF-E5RK12-F1, skipping.
# One-hot file already exists for AF-A0A0U1RQW0-F1, skipping.
# One-hot file already exists for AF-F8WDJ0-F1, skipping.
# One-hot file already exists for AF-R4GMV2-F1, skipping.
# One-hot file already exists for AF-B7Z3P7-F1, skipping.
# One-hot file already exists for AF-A0A1B0GUE8-F1, skipping.
# One-hot file already exists for 6wr4, skipping.
# One-hot file already exists for AF-A0A7I2V5A1-F1, skipping.
# One-hot file already exists for AF-H7BXN9-F1, skipping.
# One-hot file already exists for AF-A0A140T9P5-F1, skipping.
# One-hot file already exists for AF-K7EIE4-F1, skipping.
# One-hot file already exists for AF-Q8IY22-F1, skipping.
# One-hot file already exists for AF-E5RGN9-F1, skipping.
# One-hot file already exists for AF-K7EJZ1-F1, skipping.
# One-hot file already exists for AF-Q5JZ02-F1, skipping.
# One-hot file already exists for AF-E9PRQ3-F1, skipping.
# One-hot file already exists for AF-H3BT13-F1, skipping.
# One-hot file already exists for AF-Q6UXZ3-F1, skipping.
# One-hot file already exists for AF-Q9UK28-F1, skipping.
# One-hot file already exists for AF-C9J9N0-F1, skipping.
# One-hot file already exists for AF-H3BNI4-F1, skipping.
# One-hot file already exists for AF-B5ME96-F1, skipping.
# One-hot file already exists for AF-P38432-F1, skipping.
# One-hot file already exists for AF-Q5JUQ2-F1, skipping.
# One-hot file already exists for AF-H0YKW5-F1, skipping.
# One-hot file already exists for AF-A0A087WY29-F1, skipping.
# One-hot file already exists for 7ehl, skipping.
# One-hot file already exists for AF-C9JZA2-F1, skipping.
# One-hot file already exists for AF-B1AMV8-F1, skipping.
# One-hot file already exists for AF-D6RFE7-F1, skipping.
# One-hot file already exists for AF-A0A2R8Y646-F1, skipping.
# One-hot file already exists for AF-Q9BUE6-F1, skipping.
# One-hot file already exists for AF-F8WE69-F1, skipping.
# One-hot file already exists for AF-H0YNG7-F1, skipping.
# One-hot file already exists for AF-Q9HCM1-F1, skipping.
# One-hot file already exists for AF-F8W041-F1, skipping.
# One-hot file already exists for AF-D6RG10-F1, skipping.
# One-hot file already exists for AF-B0QZ99-F1, skipping.
# One-hot file already exists for AF-A0A087WZA0-F1, skipping.
# One-hot file already exists for 6uej, skipping.
# One-hot file already exists for AF-Q8N9G1-F1, skipping.
# One-hot file already exists for AF-D6RJH4-F1, skipping.
# One-hot file already exists for AF-G3V3K3-F1, skipping.
# One-hot file already exists for AF-A0A0G2JMA3-F1, skipping.
# One-hot file already exists for AF-C9JLB5-F1, skipping.
# One-hot file already exists for AF-H3BTX6-F1, skipping.
# One-hot file already exists for 7z1t, skipping.
# One-hot file already exists for AF-H7C498-F1, skipping.
# One-hot file already exists for AF-A0A075B6J2-F1, skipping.
# One-hot file already exists for AF-F8VV69-F1, skipping.
# One-hot file already exists for AF-E3W988-F1, skipping.
# One-hot file already exists for AF-E9PH25-F1, skipping.
# One-hot file already exists for AF-E9PI46-F1, skipping.
# One-hot file already exists for AF-A8MUA9-F1, skipping.
# One-hot file already exists for AF-Q9Y3D5-F1, skipping.
# One-hot file already exists for AF-A0A7P0T984-F1, skipping.
# One-hot file already exists for AF-A0A2R8Y7W9-F1, skipping.
# One-hot file already exists for AF-S4R387-F1, skipping.
# One-hot file already exists for 7l97, skipping.
# One-hot file already exists for AF-Q96B33-F1, skipping.
# One-hot file already exists for AF-H0YNT6-F1, skipping.
# One-hot file already exists for 2l58, skipping.
# One-hot file already exists for AF-K7EJU0-F1, skipping.
# One-hot file already exists for AF-F6R503-F1, skipping.
# One-hot file already exists for 5u7z, skipping.
# One-hot file already exists for AF-P0C881-F1, skipping.
# One-hot file already exists for AF-U3KPY5-F1, skipping.
# One-hot file already exists for AF-I3L2V7-F1, skipping.
# One-hot file already exists for AF-B0QYD3-F1, skipping.
# One-hot file already exists for AF-A0A2R8YFH6-F1, skipping.
# One-hot file already exists for AF-Q08648-F1, skipping.
# One-hot file already exists for AF-E2QRP2-F1, skipping.
# One-hot file already exists for AF-Q7Z6K1-F1, skipping.
# One-hot file already exists for AF-H3BP16-F1, skipping.
# One-hot file already exists for AF-M0QXW6-F1, skipping.
# One-hot file already exists for AF-Q5H928-F1, skipping.
# One-hot file already exists for AF-L7N489-F1, skipping.
# One-hot file already exists for AF-F8WBE5-F1, skipping.
# One-hot file already exists for AF-Q96JA4-F1, skipping.
# One-hot file already exists for 1xaw, skipping.
# One-hot file already exists for 2d46, skipping.
# One-hot file already exists for AF-E9PIK7-F1, skipping.
# One-hot file already exists for AF-B1AMX7-F1, skipping.
# One-hot file already exists for AF-A0A1B0GUQ8-F1, skipping.
# One-hot file already exists for AF-F8W0N5-F1, skipping.
# One-hot file already exists for AF-A8MT87-F1, skipping.
# One-hot file already exists for AF-H7C273-F1, skipping.
# One-hot file already exists for AF-Q5TGZ0-F1, skipping.
# One-hot file already exists for 2lau, skipping.
# One-hot file already exists for AF-Q8WY22-F1, skipping.
# One-hot file already exists for AF-A2ABH4-F1, skipping.
# One-hot file already exists for AF-P23415-F1, skipping.
# One-hot file already exists for AF-A0A804HLI2-F1, skipping.
# One-hot file already exists for AF-A0A7I2V2Q2-F1, skipping.
# One-hot file already exists for AF-A0A096LP07-F1, skipping.
# One-hot file already exists for 3a8y, skipping.
# One-hot file already exists for AF-A0A024R6J8-F1, skipping.
# One-hot file already exists for 5bo8, skipping.
# One-hot file already exists for AF-G3V5B5-F1, skipping.
# One-hot file already exists for AF-E9PLA6-F1, skipping.
# One-hot file already exists for AF-Q3ZK31-F1, skipping.
# One-hot file already exists for AF-A4QPB6-F1, skipping.
# One-hot file already exists for 4m7r, skipping.
# One-hot file already exists for AF-F5H303-F1, skipping.
# One-hot file already exists for AF-Q5VWT5-F1, skipping.
# One-hot file already exists for AF-S4R3U9-F1, skipping.
# One-hot file already exists for AF-Q6ZSG2-F1, skipping.
# One-hot file already exists for AF-Q9ULQ1-F1, skipping.
# One-hot file already exists for AF-G3V4E4-F1, skipping.
# One-hot file already exists for AF-Q14566-F1, skipping.
# One-hot file already exists for 7egf, skipping.
# One-hot file already exists for AF-A0A3B3ISL9-F1, skipping.
# One-hot file already exists for AF-Q9NYF0-F1, skipping.
# One-hot file already exists for AF-B4DDQ3-F1, skipping.
# One-hot file already exists for AF-Q2M3G0-F1, skipping.
# One-hot file already exists for AF-B9A054-F1, skipping.
# One-hot file already exists for 4n2k, skipping.
# One-hot file already exists for AF-O15213-F1, skipping.
# Voronoi image not found for 4pl8, skipping.
# One-hot file already exists for AF-Q13797-F1, skipping.
# Voronoi image not found for 2j51, skipping.
# One-hot file already exists for AF-Q9UJ68-F1, skipping.
# Voronoi image not found for 7y68, skipping.
# Voronoi image not found for 8cbl, skipping.
# Voronoi image not found for 9bz4, skipping.
# One-hot file already exists for AF-P0C5K6-F1, skipping.
# One-hot file already exists for 5wa1, skipping.
# Voronoi image not found for 7ciq, skipping.
# One-hot file already exists for AF-O75074-F1, skipping.
# Voronoi image not found for 6uri, skipping.
# One-hot file already exists for AF-A2RRP1-F1, skipping.
# Voronoi image not found for 4hdq, skipping.
# One-hot file already exists for AF-Q15029-F1, skipping.
# Voronoi image not found for 1b34, skipping.
# One-hot file already exists for AF-Q9GZR7-F1, skipping.
# One-hot file already exists for 6bjc, skipping.
# One-hot file already exists for 4kng, skipping.
# One-hot file already exists for 1z8g, skipping.
# One-hot file already exists for AF-O60224-F1, skipping.
# One-hot file already exists for 5jno, skipping.
# One-hot file already exists for AF-Q52LW3-F1, skipping.
# One-hot file already exists for 7yxy, skipping.
# One-hot file already exists for 5j7e, skipping.
# One-hot file already exists for AF-P78396-F1, skipping.
# One-hot file already exists for AF-P43362-F1, skipping.
# One-hot file already exists for 5mio, skipping.
# One-hot file already exists for AF-Q5VT25-F1, skipping.
# One-hot file already exists for 5gjh, skipping.
# One-hot file already exists for AF-Q15506-F1, skipping.
# One-hot file already exists for AF-Q9H8N7-F1, skipping.
# One-hot file already exists for 6u26, skipping.
# One-hot file already exists for 6bsc, skipping.
# One-hot file already exists for 4f02, skipping.
# One-hot file already exists for 7mhy, skipping.
# One-hot file already exists for 2yw8, skipping.
# One-hot file already exists for AF-Q5EG05-F1, skipping.
# One-hot file already exists for 5ucx, skipping.
# One-hot file already exists for 3s2k, skipping.
# One-hot file already exists for 7vf2, skipping.
# One-hot file already exists for 7jvx, skipping.
# One-hot file already exists for 6kor, skipping.
# One-hot file already exists for 8bgu, skipping.
# One-hot file already exists for 4cnm, skipping.
# One-hot file already exists for 1ujd, skipping.
# One-hot file already exists for 2w96, skipping.
# One-hot file already exists for AF-Q5H9U9-F1, skipping.
# One-hot file already exists for 2q5e, skipping.
# One-hot file already exists for 8s24, skipping.
# One-hot file already exists for AF-Q13072-F1, skipping.
# One-hot file already exists for AF-A1L0T0-F1, skipping.
# One-hot file already exists for 2xqn, skipping.
# One-hot file already exists for AF-Q14590-F1, skipping.
# One-hot file already exists for AF-Q9BYK8-F1, skipping.
# One-hot file already exists for 1dp7, skipping.
# One-hot file already exists for AF-O94952-F1, skipping.
# One-hot file already exists for AF-Q969W1-F1, skipping.
# One-hot file already exists for 2dyp, skipping.
# One-hot file already exists for 5lzk, skipping.
# One-hot file already exists for AF-Q5VYK3-F1, skipping.
# One-hot file already exists for 2l5g, skipping.
# One-hot file already exists for AF-P43360-F1, skipping.
# One-hot file already exists for AF-Q8N8U9-F1, skipping.
# One-hot file already exists for AF-O60292-F1, skipping.
# One-hot file already exists for 1wel, skipping.
# One-hot file already exists for AF-Q6W4X9-F1, skipping.
# One-hot file already exists for 7qxa, skipping.
# One-hot file already exists for 1wgd, skipping.
# One-hot file already exists for 5nvk, skipping.
# One-hot file already exists for AF-O14525-F1, skipping.
# One-hot file already exists for 4az9, skipping.
# One-hot file already exists for AF-Q13496-F1, skipping.
# One-hot file already exists for AF-O75204-F1, skipping.
# One-hot file already exists for AF-Q9Y276-F1, skipping.
# One-hot file already exists for AF-P43356-F1, skipping.
# One-hot file already exists for 6otn, skipping.
# One-hot file already exists for AF-Q9HAW4-F1, skipping.
# One-hot file already exists for AF-Q7L3B6-F1, skipping.
# One-hot file already exists for 8xya, skipping.
# One-hot file already exists for 2crp, skipping.
# One-hot file already exists for AF-Q6NUQ1-F1, skipping.
# One-hot file already exists for 1txd, skipping.
# One-hot file already exists for AF-Q75T13-F1, skipping.
# One-hot file already exists for AF-P57082-F1, skipping.
# One-hot file already exists for 7nx3, skipping.
# One-hot file already exists for 2qw4, skipping.
# One-hot file already exists for 2qtl, skipping.
# One-hot file already exists for AF-Q99459-F1, skipping.
# One-hot file already exists for 1x4u, skipping.
# One-hot file already exists for AF-Q9BTX1-F1, skipping.
# One-hot file already exists for AF-Q96S97-F1, skipping.
# One-hot file already exists for 6at5, skipping.
# One-hot file already exists for 8skz, skipping.
# One-hot file already exists for 7rsq, skipping.
# One-hot file already exists for 5v07, skipping.
# One-hot file already exists for AF-Q86VR2-F1, skipping.
# One-hot file already exists for 8hpp, skipping.
# One-hot file already exists for AF-Q8TBZ0-F1, skipping.
# One-hot file already exists for 1sg4, skipping.
# One-hot file already exists for 4frw, skipping.
# One-hot file already exists for 6kbr, skipping.
# One-hot file already exists for 3ctz, skipping.
# One-hot file already exists for AF-Q66K89-F1, skipping.
# One-hot file already exists for AF-Q8NFW1-F1, skipping.
# One-hot file already exists for 7ch1, skipping.
# One-hot file already exists for 8gnn, skipping.
# One-hot file already exists for 5lb8, skipping.
# One-hot file already exists for 4mzv, skipping.
# One-hot file already exists for 5yz0, skipping.
# One-hot file already exists for AF-Q6S8J3-F1, skipping.
# One-hot file already exists for 7syd, skipping.
# One-hot file already exists for AF-Q8NGG8-F1, skipping.
# One-hot file already exists for 4m9p, skipping.
# One-hot file already exists for 5ltu, skipping.
# One-hot file already exists for 7x1n, skipping.
# One-hot file already exists for 2aex, skipping.
# One-hot file already exists for AF-Q6ZSS7-F1, skipping.
# One-hot file already exists for 9bz0, skipping.
# One-hot file already exists for 2ha8, skipping.
# One-hot file already exists for 3pbh, skipping.
# One-hot file already exists for AF-P48145-F1, skipping.
# One-hot file already exists for AF-Q9BRL7-F1, skipping.
# One-hot file already exists for 7rk7, skipping.
# One-hot file already exists for 8a9j, skipping.
# One-hot file already exists for AF-Q9HD64-F1, skipping.
# One-hot file already exists for AF-Q17RY6-F1, skipping.
# One-hot file already exists for AF-Q9C091-F1, skipping.
# One-hot file already exists for 6f9n, skipping.
# One-hot file already exists for 2zch, skipping.
# One-hot file already exists for 8a1f, skipping.
# One-hot file already exists for 9e4q, skipping.
# One-hot file already exists for AF-Q8WYK1-F1, skipping.
# One-hot file already exists for 3l6f, skipping.
# One-hot file already exists for 2o6l, skipping.
# One-hot file already exists for AF-Q9Y4A9-F1, skipping.
# One-hot file already exists for 6zio, skipping.
# One-hot file already exists for AF-Q6UB98-F1, skipping.
# One-hot file already exists for 7ob9, skipping.
# One-hot file already exists for AF-P51878-F1, skipping.
# One-hot file already exists for AF-Q8IY85-F1, skipping.
# One-hot file already exists for 7cmm, skipping.
# One-hot file already exists for 6lth, skipping.
# One-hot file already exists for 7xv1, skipping.
# One-hot file already exists for 8ynm, skipping.
# One-hot file already exists for AF-Q13296-F1, skipping.
# One-hot file already exists for AF-Q00973-F1, skipping.
# One-hot file already exists for 8rrh, skipping.
# One-hot file already exists for AF-P54259-F1, skipping.
# One-hot file already exists for AF-Q9Y5P2-F1, skipping.
# One-hot file already exists for 6blw, skipping.
# One-hot file already exists for AF-O15397-F1, skipping.
# One-hot file already exists for 4ftg, skipping.
# One-hot file already exists for AF-Q08397-F1, skipping.
# One-hot file already exists for 4uyi, skipping.
# One-hot file already exists for AF-Q7Z478-F1, skipping.
# One-hot file already exists for 3ihx, skipping.
# One-hot file already exists for AF-O14578-F1, skipping.
# One-hot file already exists for AF-Q8N7R7-F1, skipping.
# One-hot file already exists for AF-Q8WVB6-F1, skipping.
# One-hot file already exists for 8jca, skipping.
# One-hot file already exists for AF-Q9UJF2-F1, skipping.
# One-hot file already exists for AF-Q9P1Y6-F1, skipping.
# One-hot file already exists for 5x7x, skipping.
# One-hot file already exists for AF-Q9BYW2-F1, skipping.
# One-hot file already exists for AF-Q5VZL5-F1, skipping.
# One-hot file already exists for 7sqk, skipping.
# One-hot file already exists for AF-Q6NUM9-F1, skipping.
# One-hot file already exists for AF-Q9BX69-F1, skipping.
# One-hot file already exists for 6uva, skipping.
# One-hot file already exists for 6i3v, skipping.
# One-hot file already exists for 7oy0, skipping.
# One-hot file already exists for 9d37, skipping.
# One-hot file already exists for 5lkr, skipping.
# One-hot file already exists for AF-Q9UBF1-F1, skipping.
# One-hot file already exists for 8ucd, skipping.
# One-hot file already exists for AF-Q9NP56-F1, skipping.
# One-hot file already exists for 1eh2, skipping.
# One-hot file already exists for AF-Q9UKP4-F1, skipping.
# One-hot file already exists for 5mv9, skipping.
# One-hot file already exists for 1tg6, skipping.
# One-hot file already exists for 2mze, skipping.
# One-hot file already exists for AF-Q99689-F1, skipping.
# One-hot file already exists for AF-P63313-F1, skipping.
# One-hot file already exists for 7b2g, skipping.
# One-hot file already exists for 7uhy, skipping.
# One-hot file already exists for 1hcn, skipping.
# One-hot file already exists for 8css, skipping.
# One-hot file already exists for AF-Q5TDP6-F1, skipping.
# One-hot file already exists for AF-Q15735-F1, skipping.
# One-hot file already exists for 6qly, skipping.
# One-hot file already exists for 5c40, skipping.
# One-hot file already exists for 8fbz, skipping.
# One-hot file already exists for 8hmz, skipping.
# One-hot file already exists for 7urd, skipping.
# One-hot file already exists for AF-Q8WVC6-F1, skipping.
# One-hot file already exists for AF-Q6ZU65-F1, skipping.
# One-hot file already exists for 6khf, skipping.
# One-hot file already exists for 1khx, skipping.
# One-hot file already exists for AF-Q8N0Z3-F1, skipping.
# One-hot file already exists for 6id1, skipping.
# One-hot file already exists for 6n8r, skipping.
# One-hot file already exists for 7z8b, skipping.
# One-hot file already exists for 6gfa, skipping.
# One-hot file already exists for AF-Q16706-F1, skipping.
# One-hot file already exists for 7ml7, skipping.
# One-hot file already exists for AF-O95864-F1, skipping.
# One-hot file already exists for 8wns, skipping.
# One-hot file already exists for AF-Q99541-F1, skipping.
# One-hot file already exists for AF-Q96Q45-F1, skipping.
# One-hot file already exists for AF-Q9UJW7-F1, skipping.
# One-hot file already exists for AF-P28300-F1, skipping.
# One-hot file already exists for AF-P08670-F1, skipping.
# One-hot file already exists for AF-Q8IWA0-F1, skipping.
# One-hot file already exists for 8fy0, skipping.
# One-hot file already exists for 7yea, skipping.
# One-hot file already exists for 1snl, skipping.
# One-hot file already exists for AF-Q3KPI0-F1, skipping.
# One-hot file already exists for AF-O15374-F1, skipping.
# One-hot file already exists for 8trh, skipping.
# One-hot file already exists for AF-Q6ZRQ5-F1, skipping.
# One-hot file already exists for AF-Q08378-F1, skipping.
# One-hot file already exists for 1z2c, skipping.
# One-hot file already exists for AF-Q5JVG8-F1, skipping.
# One-hot file already exists for AF-Q9Y5R8-F1, skipping.
# One-hot file already exists for 7evs, skipping.
# One-hot file already exists for 6s7o, skipping.
# One-hot file already exists for AF-Q6UWU4-F1, skipping.
# One-hot file already exists for AF-Q8TE54-F1, skipping.
# One-hot file already exists for 4j81, skipping.
# One-hot file already exists for AF-Q16478-F1, skipping.
# One-hot file already exists for 7qdy, skipping.
# One-hot file already exists for AF-Q14003-F1, skipping.
# One-hot file already exists for 7jq9, skipping.
# One-hot file already exists for 8egw, skipping.
# One-hot file already exists for 4o2w, skipping.
# One-hot file already exists for 8era, skipping.
# One-hot file already exists for 5l04, skipping.
# One-hot file already exists for AF-Q9C093-F1, skipping.
# One-hot file already exists for 4fcj, skipping.
# One-hot file already exists for 1w7b, skipping.
# One-hot file already exists for AF-Q9NVN8-F1, skipping.
# One-hot file already exists for AF-Q9C0I3-F1, skipping.
# One-hot file already exists for AF-Q6RI45-F1, skipping.
# One-hot file already exists for 7qpj, skipping.
# One-hot file already exists for 9jst, skipping.
# One-hot file already exists for 6kiw, skipping.
# One-hot file already exists for AF-Q6NUT2-F1, skipping.
# One-hot file already exists for 2w18, skipping.
# One-hot file already exists for AF-Q9HCK1-F1, skipping.
# One-hot file already exists for AF-O00339-F1, skipping.
# One-hot file already exists for 6l54, skipping.
# One-hot file already exists for 3l8i, skipping.
# One-hot file already exists for AF-O75083-F1, skipping.
# One-hot file already exists for AF-Q13023-F1, skipping.
# One-hot file already exists for 3g33, skipping.
# One-hot file already exists for AF-Q4G112-F1, skipping.
# One-hot file already exists for AF-Q969T4-F1, skipping.
# One-hot file already exists for AF-P31513-F1, skipping.
# One-hot file already exists for AF-Q8TCP9-F1, skipping.
# One-hot file already exists for 8fna, skipping.
# One-hot file already exists for AF-P51810-F1, skipping.
# One-hot file already exists for 8ari, skipping.
# One-hot file already exists for 7etw, skipping.
# One-hot file already exists for 3lb6, skipping.
# One-hot file already exists for 6snk, skipping.
# One-hot file already exists for AF-Q96C01-F1, skipping.
# One-hot file already exists for AF-Q96B01-F1, skipping.
# One-hot file already exists for AF-O75439-F1, skipping.
# One-hot file already exists for 6wwz, skipping.
# One-hot file already exists for 1b6e, skipping.
# One-hot file already exists for 8r1f, skipping.
# One-hot file already exists for 6kkr, skipping.
# One-hot file already exists for 7cxr, skipping.
# One-hot file already exists for 6wnx, skipping.
# One-hot file already exists for AF-Q5H943-F1, skipping.
# One-hot file already exists for 4zri, skipping.
# One-hot file already exists for AF-Q6IBW4-F1, skipping.
# One-hot file already exists for AF-Q8IXL9-F1, skipping.
# One-hot file already exists for 6nl3, skipping.
# One-hot file already exists for AF-P46734-F1, skipping.
# One-hot file already exists for 7znk, skipping.
# One-hot file already exists for AF-Q6STE5-F1, skipping.
# One-hot file already exists for 4v0p, skipping.
# One-hot file already exists for 4f9c, skipping.
# One-hot file already exists for AF-Q9NQZ7-F1, skipping.
# One-hot file already exists for AF-Q86XZ4-F1, skipping.
# One-hot file already exists for 6l5n, skipping.
# One-hot file already exists for 5bs0, skipping.
# One-hot file already exists for 4z18, skipping.
# One-hot file already exists for 7yim, skipping.
# One-hot file already exists for AF-Q86UW7-F1, skipping.
# One-hot file already exists for 2fh7, skipping.
# One-hot file already exists for AF-O60813-F1, skipping.
# One-hot file already exists for AF-Q9Y3R5-F1, skipping.
# One-hot file already exists for AF-Q04725-F1, skipping.
# One-hot file already exists for 7pzr, skipping.
# One-hot file already exists for AF-Q68CL5-F1, skipping.
# One-hot file already exists for AF-Q00610-F1, skipping.
# One-hot file already exists for 1ain, skipping.
# One-hot file already exists for 6sub, skipping.
# One-hot file already exists for 8dwu, skipping.
# One-hot file already exists for 8fnb, skipping.
# One-hot file already exists for AF-Q9NPD3-F1, skipping.
# One-hot file already exists for 5o5t, skipping.
# One-hot file already exists for 7pmy, skipping.
# One-hot file already exists for 2h3l, skipping.
# One-hot file already exists for 6s5h, skipping.
# One-hot file already exists for 1cf7, skipping.
# One-hot file already exists for 1umk, skipping.
# One-hot file already exists for 6r2l, skipping.
# One-hot file already exists for AF-O60346-F1, skipping.
# One-hot file already exists for AF-P57740-F1, skipping.
# One-hot file already exists for AF-Q7Z388-F1, skipping.
# One-hot file already exists for AF-O43900-F1, skipping.
# One-hot file already exists for 7d13, skipping.
# One-hot file already exists for 7jjk, skipping.
# One-hot file already exists for 3hn3, skipping.
# One-hot file already exists for 5eom, skipping.
# One-hot file already exists for 8uts, skipping.
# One-hot file already exists for 3aih, skipping.
# One-hot file already exists for 1e07, skipping.
# One-hot file already exists for AF-Q6L9W6-F1, skipping.
# One-hot file already exists for AF-Q8IWA5-F1, skipping.
# One-hot file already exists for AF-Q9P215-F1, skipping.
# One-hot file already exists for AF-O75179-F1, skipping.
# One-hot file already exists for AF-P78539-F1, skipping.
# One-hot file already exists for 3b6u, skipping.
# One-hot file already exists for 8d43, skipping.
# One-hot file already exists for 7kw7, skipping.
# One-hot file already exists for 2x8a, skipping.
# One-hot file already exists for AF-P0DTW1-F1, skipping.
# One-hot file already exists for AF-Q9H2H9-F1, skipping.
# One-hot file already exists for 8qci, skipping.
# One-hot file already exists for 2z6h, skipping.
# One-hot file already exists for AF-P35658-F1, skipping.
# One-hot file already exists for 6h4i, skipping.
# One-hot file already exists for AF-Q0VG06-F1, skipping.
# One-hot file already exists for 2vwx, skipping.
# One-hot file already exists for 8hag, skipping.
# One-hot file already exists for AF-P56693-F1, skipping.
# One-hot file already exists for 6vfu, skipping.
# One-hot file already exists for 7u21, skipping.
# One-hot file already exists for 7r5r, skipping.
# One-hot file already exists for 3bo8, skipping.
# One-hot file already exists for 7nh5, skipping.
# One-hot file already exists for 9gaw, skipping.
# One-hot file already exists for 7oop, skipping.
# One-hot file already exists for 8e2a, skipping.
# One-hot file already exists for AF-Q8NH56-F1, skipping.
# One-hot file already exists for 9auc, skipping.
# One-hot file already exists for AF-Q9UM00-F1, skipping.
# One-hot file already exists for 2ebp, skipping.
# One-hot file already exists for 1gg3, skipping.
# One-hot file already exists for 3q5u, skipping.
# One-hot file already exists for AF-Q6IQ32-F1, skipping.
# One-hot file already exists for AF-Q8WY36-F1, skipping.
# One-hot file already exists for AF-O75638-F1, skipping.
# One-hot file already exists for AF-Q8TEM1-F1, skipping.
# One-hot file already exists for AF-P17643-F1, skipping.
# One-hot file already exists for AF-Q6IF42-F1, skipping.
# One-hot file already exists for 6umq, skipping.
# One-hot file already exists for 2qfa, skipping.
# One-hot file already exists for 6vrf, skipping.
# One-hot file already exists for 1so7, skipping.
# One-hot file already exists for 8d85, skipping.
# One-hot file already exists for 4bx9, skipping.
# One-hot file already exists for AF-Q9BTY2-F1, skipping.
# ...
# One-hot file already exists for AF-Q9ZLH3-F1, skipping.
# One-hot file already exists for AF-A9M1G4-F1, skipping.
# One-hot file already exists for AF-Q72S00-F1, skipping.
# One-hot file already exists for AF-B5XZ47-F1, skipping.
# One-hot file already exists for AF-B6JNE6-F1, skipping.
# One-hot file already exists for AF-B7J244-F1, skipping.
# One-hot file already exists for AF-P0ADA9-F1, skipping.
# One-hot file already exists for AF-Q9ZJX2-F1, skipping.
# One-hot file already exists for AF-O50461-F1, skipping.
# One-hot file already exists for 8ako, skipping.
# One-hot file already exists for AF-P66030-F1, skipping.
# One-hot file already exists for AF-B2RIT0-F1, skipping.
# One-hot file already exists for AF-Q8Y5N4-F1, skipping.
# One-hot file already exists for AF-Q81YT7-F1, skipping.
# One-hot file already exists for AF-Q9PK95-F1, skipping.
# One-hot file already exists for AF-Q97NZ6-F1, skipping.
# One-hot file already exists for AF-Q5X5Y6-F1, skipping.
# One-hot file already exists for AF-C1C5E1-F1, skipping.
# One-hot file already exists for AF-Q1JLD9-F1, skipping.
# One-hot file already exists for AF-Q5HEL8-F1, skipping.
# One-hot file already exists for AF-P9WH91-F1, skipping.
# One-hot file already exists for AF-Q8Y495-F1, skipping.
# One-hot file already exists for AF-O84337-F1, skipping.
# One-hot file already exists for AF-Q5XD04-F1, skipping.
# One-hot file already exists for AF-Q2FYP6-F1, skipping.
# One-hot file already exists for AF-B2UZL5-F1, skipping.
# One-hot file already exists for AF-Q714U9-F1, skipping.
# One-hot file already exists for AF-P9WJ57-F1, skipping.
# One-hot file already exists for AF-P9WJ80-F1, skipping.
# One-hot file already exists for AF-Q8E146-F1, skipping.
# One-hot file already exists for AF-P9WNE0-F1, skipping.
# One-hot file already exists for AF-A1KWN6-F1, skipping.
# One-hot file already exists for AF-B5XXL2-F1, skipping.
# One-hot file already exists for AF-P0DMM2-F1, skipping.
# One-hot file already exists for AF-Q97P15-F1, skipping.
# One-hot file already exists for AF-Q03727-F1, skipping.
# One-hot file already exists for AF-Q54957-F1, skipping.
# One-hot file already exists for AF-B7J264-F1, skipping.
# One-hot file already exists for 4jdy, skipping.
# One-hot file already exists for AF-Q1J8K6-F1, skipping.
# One-hot file already exists for AF-Q9A0E4-F1, skipping.
# One-hot file already exists for AF-P77172-F1, skipping.
# One-hot file already exists for AF-Q8FJF0-F1, skipping.
# One-hot file already exists for AF-Q02FR1-F1, skipping.
# One-hot file already exists for AF-Q5WXA8-F1, skipping.
# One-hot file already exists for AF-Q2YY05-F1, skipping.
# One-hot file already exists for AF-P23835-F1, skipping.
# One-hot file already exists for AF-A5U281-F1, skipping.
# One-hot file already exists for AF-P9WGG5-F1, skipping.
# One-hot file already exists for AF-P9WMH6-F1, skipping.
# One-hot file already exists for AF-Q9HYV7-F1, skipping.
# One-hot file already exists for AF-P9WIC5-F1, skipping.
# One-hot file already exists for AF-Q9RQP6-F1, skipping.
# One-hot file already exists for AF-P36501-F1, skipping.
# One-hot file already exists for AF-O07434-F1, skipping.
# One-hot file already exists for AF-Q81VY9-F1, skipping.
# One-hot file already exists for AF-Q9HWE3-F1, skipping.
# One-hot file already exists for AF-P0DA03-F1, skipping.
# One-hot file already exists for AF-P9WGC2-F1, skipping.
# One-hot file already exists for AF-Q9JTR9-F1, skipping.
# One-hot file already exists for AF-A7FQ53-F1, skipping.
# One-hot file already exists for AF-Q1JFY9-F1, skipping.
# One-hot file already exists for 8c41, skipping.
# One-hot file already exists for AF-P0DG85-F1, skipping.
# One-hot file already exists for AF-Q9JVF4-F1, skipping.
# One-hot file already exists for AF-Q9JWS8-F1, skipping.
# One-hot file already exists for AF-P9WIX8-F1, skipping.
# One-hot file already exists for AF-Q8DRB0-F1, skipping.
# One-hot file already exists for AF-Q48446-F1, skipping.
# One-hot file already exists for AF-P96061-F1, skipping.
# One-hot file already exists for AF-B5Z9S9-F1, skipping.
# One-hot file already exists for AF-Q5F807-F1, skipping.
# One-hot file already exists for AF-Q1JCG6-F1, skipping.
# One-hot file already exists for AF-O08397-F1, skipping.
# One-hot file already exists for 8a42, skipping.
# One-hot file already exists for AF-P9WH93-F1, skipping.
# One-hot file already exists for AF-A5U1K8-F1, skipping.
# One-hot file already exists for AF-P9WLB0-F1, skipping.
# One-hot file already exists for AF-Q93UU8-F1, skipping.
# One-hot file already exists for AF-P9WIN7-F1, skipping.
# One-hot file already exists for AF-Q6VS28-F1, skipping.
# One-hot file already exists for AF-Q6VS24-F1, skipping.
# One-hot file already exists for 7ce2, skipping.
# One-hot file already exists for AF-P96943-F1, skipping.
# One-hot file already exists for 3ecq, skipping.
# One-hot file already exists for AF-Q9RM68-F1, skipping.
# One-hot file already exists for AF-A0A0H2WYQ0-F1, skipping.
# One-hot file already exists for AF-Q9AG74-F1, skipping.
# One-hot file already exists for AF-Q8DQP7-F1, skipping.
# One-hot file already exists for AF-P9WIF5-F1, skipping.
# One-hot file already exists for 6ro0, skipping.
# One-hot file already exists for AF-P27053-F1, skipping.
# One-hot file already exists for AF-Q9ZN37-F1, skipping.
# One-hot file already exists for AF-Q99Z76-F1, skipping.
# One-hot file already exists for AF-Q9REH6-F1, skipping.
# One-hot file already exists for AF-Q48900-F1, skipping.
# One-hot file already exists for AF-Q9L5B9-F1, skipping.
# One-hot file already exists for AF-Q97QP7-F1, skipping.
# One-hot file already exists for 2mpa, skipping.
# One-hot file already exists for 1sfr, skipping.
# One-hot file already exists for AF-Q03946-F1, skipping.
# One-hot file already exists for AF-P9WG27-F1, skipping.
# One-hot file already exists for AF-P9WI32-F1, skipping.
# One-hot file already exists for AF-C6C2D6-F1, skipping.
# One-hot file already exists for AF-P0AFZ6-F1, skipping.
# One-hot file already exists for 2k0l, skipping.
# One-hot file already exists for AF-P70854-F1, skipping.
# One-hot file already exists for AF-P19649-F1, skipping.
# One-hot file already exists for AF-A0ELI3-F1, skipping.
# One-hot file already exists for 1fep, skipping.
# One-hot file already exists for 2cs7, skipping.
# One-hot file already exists for 2aiz, skipping.
# One-hot file already exists for AF-B2UW70-F1, skipping.
# One-hot file already exists for AF-Q8Z939-F1, skipping.
# One-hot file already exists for AF-P9WK64-F1, skipping.
# One-hot file already exists for AF-Q01924-F1, skipping.
# One-hot file already exists for AF-Q53348-F1, skipping.
# One-hot file already exists for 4xo9, skipping.
# One-hot file already exists for AF-P0A4S2-F1, skipping.
# One-hot file already exists for AF-B1MF62-F1, skipping.
# One-hot file already exists for 6j19, skipping.
# One-hot file already exists for AF-P23994-F1, skipping.
# One-hot file already exists for AF-P0A0R3-F1, skipping.
# One-hot file already exists for AF-P9WHW8-F1, skipping.
# One-hot file already exists for 1osp, skipping.
# One-hot file already exists for AF-P0C0I3-F1, skipping.
# One-hot file already exists for AF-A0A0H2VA37-F1, skipping.
# One-hot file already exists for AF-P9WIP9-F1, skipping.
# One-hot file already exists for 1n67, skipping.
# One-hot file already exists for AF-Q6MWX1-F1, skipping.
# One-hot file already exists for 1ikp, skipping.
# One-hot file already exists for 6ya1, skipping.
# One-hot file already exists for AF-B9VX92-F1, skipping.
# One-hot file already exists for AF-P9WP41-F1, skipping.
# One-hot file already exists for 7nhz, skipping.
# One-hot file already exists for AF-Q9A0A2-F1, skipping.
# One-hot file already exists for AF-Q9A147-F1, skipping.
# One-hot file already exists for AF-P59652-F1, skipping.
# One-hot file already exists for AF-P9WG31-F1, skipping.
# One-hot file already exists for 5m6d, skipping.
# One-hot file already exists for AF-Q8VQ82-F1, skipping.
# One-hot file already exists for AF-Q99YU2-F1, skipping.
# One-hot file already exists for AF-A0A0H2ZLS0-F1, skipping.
# One-hot file already exists for AF-Q06947-F1, skipping.
# One-hot file already exists for 2lqu, skipping.
# One-hot file already exists for AF-P19542-F1, skipping.
# One-hot file already exists for AF-B2RGR5-F1, skipping.
# One-hot file already exists for 1s8n, skipping.
# One-hot file already exists for AF-Q9S6N1-F1, skipping.
# One-hot file already exists for 2fjc, skipping.
# One-hot file already exists for AF-P9WNJ2-F1, skipping.
# One-hot file already exists for AF-Q9A080-F1, skipping.
# One-hot file already exists for AF-A0A0G4BZT3-F1, skipping.
# One-hot file already exists for AF-B2RLK2-F1, skipping.
# One-hot file already exists for AF-Q9X3R6-F1, skipping.
# One-hot file already exists for 1kho, skipping.
# One-hot file already exists for 4cge, skipping.
# One-hot file already exists for AF-P25731-F1, skipping.
# One-hot file already exists for AF-Q9Z4J8-F1, skipping.
# One-hot file already exists for AF-A0A0H2XFA2-F1, skipping.
# One-hot file already exists for 3sy7, skipping.
# One-hot file already exists for AF-A0A0H2V663-F1, skipping.
# One-hot file already exists for AF-A0A0D6H099-F1, skipping.
# One-hot file already exists for AF-O07175-F1, skipping.
# One-hot file already exists for AF-P0A468-F1, skipping.
# One-hot file already exists for AF-P21171-F1, skipping.
# One-hot file already exists for AF-P9WMK1-F1, skipping.
# One-hot file already exists for AF-P20626-F1, skipping.
# One-hot file already exists for AF-Q9RN24-F1, skipping.
# One-hot file already exists for AF-P0DH58-F1, skipping.
# One-hot file already exists for AF-A0A0I9AIV3-F1, skipping.
# One-hot file already exists for AF-Q01996-F1, skipping.
# One-hot file already exists for AF-Q93SI8-F1, skipping.
# One-hot file already exists for 3cis, skipping.
# One-hot file already exists for 1w74, skipping.
# One-hot file already exists for AF-Q5D8C1-F1, skipping.
# One-hot file already exists for AF-A0A125WA94-F1, skipping.
# One-hot file already exists for AF-P9WP43-F1, skipping.
# One-hot file already exists for AF-A6QIG2-F1, skipping.
# One-hot file already exists for 7pl2, skipping.
# One-hot file already exists for AF-Q9ZKX5-F1, skipping.
# One-hot file already exists for AF-O05166-F1, skipping.
# One-hot file already exists for 1dyq, skipping.
# One-hot file already exists for AF-P0A0U9-F1, skipping.
# One-hot file already exists for 1w9r, skipping.
# One-hot file already exists for AF-P9WGU0-F1, skipping.
# One-hot file already exists for 1y5h, skipping.
# One-hot file already exists for AF-Q9JYI8-F1, skipping.
# One-hot file already exists for AF-A0A0S3PN25-F1, skipping.
# One-hot file already exists for AF-Q99Y99-F1, skipping.
# One-hot file already exists for AF-F4YYF6-F1, skipping.
# One-hot file already exists for AF-O52987-F1, skipping.
# One-hot file already exists for AF-Q99YF6-F1, skipping.
# One-hot file already exists for AF-P71916-F1, skipping.
# One-hot file already exists for AF-Q8E5E5-F1, skipping.
# One-hot file already exists for 1osm, skipping.
# One-hot file already exists for AF-Q53990-F1, skipping.
# One-hot file already exists for AF-P0A4G3-F1, skipping.
# One-hot file already exists for 1nyo, skipping.
# One-hot file already exists for AF-Q9A1Z8-F1, skipping.
# One-hot file already exists for AF-Q99ZH4-F1, skipping.
# One-hot file already exists for AF-Q8E2U6-F1, skipping.
# One-hot file already exists for AF-P43838-F1, skipping.
# One-hot file already exists for 2hhi, skipping.
# One-hot file already exists for AF-O30405-F1, skipping.
# One-hot file already exists for 1wa8, skipping.
# One-hot file already exists for AF-I6Y1F5-F1, skipping.
# One-hot file already exists for 7bj3, skipping.
# One-hot file already exists for 6vjb, skipping.
# One-hot file already exists for AF-O53478-F1, skipping.
# One-hot file already exists for 1dm0, skipping.
# One-hot file already exists for 2hdi, skipping.
# One-hot file already exists for AF-P9WNF2-F1, skipping.
# One-hot file already exists for AF-Q46412-F1, skipping.
# One-hot file already exists for 2pms, skipping.
# One-hot file already exists for AF-P9WIP0-F1, skipping.
# One-hot file already exists for AF-E3PYQ3-F1, skipping.
# One-hot file already exists for 4x36, skipping.
# One-hot file already exists for AF-P9WG61-F1, skipping.
# One-hot file already exists for AF-A0A299MDG7-F1, skipping.
# One-hot file already exists for 4ofq, skipping.
# One-hot file already exists for 1ggq, skipping.
# One-hot file already exists for AF-P15488-F1, skipping.
# One-hot file already exists for AF-Q08137-F1, skipping.
# One-hot file already exists for AF-Q03947-F1, skipping.
# One-hot file already exists for AF-Q9ZHG7-F1, skipping.
# One-hot file already exists for AF-P9WHZ2-F1, skipping.
# One-hot file already exists for AF-Q9JPQ6-F1, skipping.
# One-hot file already exists for AF-P9WQN6-F1, skipping.
# One-hot file already exists for AF-P9WLF5-F1, skipping.
# One-hot file already exists for AF-Q9A1H3-F1, skipping.
# One-hot file already exists for AF-A0A0H2VCA1-F1, skipping.
# One-hot file already exists for 6rc9, skipping.
# One-hot file already exists for 2kg7, skipping.
# One-hot file already exists for AF-A4TSQ1-F1, skipping.
# One-hot file already exists for 6g5g, skipping.
# One-hot file already exists for 1p4p, skipping.
# One-hot file already exists for AF-Q9PJK1-F1, skipping.
# One-hot file already exists for AF-Q7X3W5-F1, skipping.
# One-hot file already exists for AF-P11221-F1, skipping.
# One-hot file already exists for 5w95, skipping.
# One-hot file already exists for 8hr4, skipping.
# One-hot file already exists for 1djr, skipping.
# One-hot file already exists for AF-O53842-F1, skipping.
# One-hot file already exists for AF-Q5HGV4-F1, skipping.
# One-hot file already exists for AF-Q48427-F1, skipping.
# One-hot file already exists for AF-A0A0H2US70-F1, skipping.
# One-hot file already exists for AF-Q9K105-F1, skipping.
# One-hot file already exists for AF-Q9Z374-F1, skipping.
# One-hot file already exists for 8cwp, skipping.
# One-hot file already exists for AF-P9WIR0-F1, skipping.
# One-hot file already exists for AF-P9WGT8-F1, skipping.
# One-hot file already exists for AF-E3PPC5-F1, skipping.
# One-hot file already exists for AF-Q9A1G0-F1, skipping.
# One-hot file already exists for 5nod, skipping.
# One-hot file already exists for AF-Q8DPQ2-F1, skipping.
# One-hot file already exists for 4ayn, skipping.
# One-hot file already exists for AF-O50430-F1, skipping.
# One-hot file already exists for AF-Q7BVH7-F1, skipping.
# One-hot file already exists for AF-O50408-F1, skipping.
# One-hot file already exists for AF-P9WGT6-F1, skipping.
# One-hot file already exists for 4l05, skipping.
# One-hot file already exists for AF-Q47119-F1, skipping.
# One-hot file already exists for 4rlc, skipping.
# One-hot file already exists for AF-Q97T80-F1, skipping.
# One-hot file already exists for AF-O84047-F1, skipping.
# One-hot file already exists for AF-Q45321-F1, skipping.
# One-hot file already exists for AF-Q9A135-F1, skipping.
# One-hot file already exists for AF-Q87L97-F1, skipping.
# One-hot file already exists for AF-Q9ZMJ1-F1, skipping.
# One-hot file already exists for AF-Q9JPH1-F1, skipping.
# One-hot file already exists for AF-Q93G68-F1, skipping.
# One-hot file already exists for AF-Q8ZP50-F1, skipping.
# One-hot file already exists for 4b0m, skipping.
# One-hot file already exists for 3pa8, skipping.
# One-hot file already exists for 5hzp, skipping.
# One-hot file already exists for 5m18, skipping.
# One-hot file already exists for AF-Q47232-F1, skipping.
# One-hot file already exists for AF-B7IZU3-F1, skipping.
# One-hot file already exists for AF-M4JCN0-F1, skipping.
# One-hot file already exists for 8z9b, skipping.
# One-hot file already exists for AF-P9WJD7-F1, skipping.
# One-hot file already exists for AF-O34097-F1, skipping.
# One-hot file already exists for AF-Q4TUW2-F1, skipping.
# One-hot file already exists for AF-A0Q465-F1, skipping.
# One-hot file already exists for AF-O30527-F1, skipping.
# One-hot file already exists for 1p4t, skipping.
# One-hot file already exists for AF-A0A0G4BZT2-F1, skipping.
# One-hot file already exists for 4ayi, skipping.
# One-hot file already exists for AF-P45996-F1, skipping.
# One-hot file already exists for AF-P01555-F1, skipping.
# One-hot file already exists for AF-Q5HIB3-F1, skipping.
# One-hot file already exists for AF-Q5ZXP3-F1, skipping.
